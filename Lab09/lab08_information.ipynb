# %% [markdown]
# ### Exercise 1 — Entropy of Neural Responses

# %%
pip install numpy
# Out:
# ...
#
# [notice] A new release of pip is available: 25.3 -> 26.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# ...
#
# [notice] A new release of pip is available: 25.3 -> 26.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import matplotlib.pyplot as plt
from entropy_utils import compute_entropy,normalize_distribution

# %% [markdown]
# ### Exercise 2 — Mutual Information

# %%
# Simulate Stimulus-Response Mapping
np.random.seed(0)

stimulus = np.random.choice([0, 1], size=1000)

response = stimulus + np.random.normal(0, 0.5, size=1000)
response = (response > 0.5).astype(int)

# %%
# Compute MI
from mutual_information import compute_mutual_information

I = compute_mutual_information(stimulus, response)
print("Mutual Information:", I, "bits")
# Out:
# Mutual Information: 0.4263533917403184 bits

# %% [markdown]
# ### Task
# Increase noise.
# Observe MI change.
# Explain why.
#
#
# Mutual Information decreases.
# Why?
# Noise makes responses less related to stimulus.
# Observing response tells us less about stimulus.
# Uncertainty reduction becomes smaller.

# %% [markdown]
# ### Exercise 3 — Spike Timing Information

# %%
#Create two spike trains:
train_A = [10, 20, 30]
train_B = [70, 80, 90]

# %%
from spike_train_analysis import compute_spike_train_entropy

# %% [markdown]
# ### Compare entropy using:
#
# Bin size = 100 ms
# Bin size = 10 ms
#
# Explain difference.
#
# | Bin Size | Effect                                          |
# | -------- | ----------------------------------------------- |
# | 100 ms   | coarse timing → fewer patterns → lower entropy  |
# | 10 ms    | precise timing → more patterns → higher entropy |

# %% [markdown]
# ### Exercise 4 — Coding Efficiency

# %%
from coding_efficiency import compare_distributions

compare_distributions()
# Out:
# Uniform entropy: 2.0 bits
# Skewed entropy: 1.3567796494470397 bits
# Uniform distribution is more efficient.

# %% [markdown]
# ##### Which distribution is more efficient?
# ##### Why does uniform maximize entropy?
#
# Uniform distribution is more efficient
# Because:
# All responses equally likely
# Maximum uncertainty
# Maximum information capacity
# Uniform ⇒ maximum entropy

# %% [markdown]
# ### Critical Thinking Questions
# ##### Can a neuron have high entropy but low mutual information? Explain.
# Yes.
# A neuron can fire randomly:
# many possible responses (high entropy)
# unrelated to stimulus (low MI)
#
# ##### Why does noise reduce mutual information?
# Noise breaks stimulus–response relationship.
#
# ##### How does bin size affect spike train entropy?
# Smaller bins preserve timing → higher entropy.
#
# ##### Does higher firing rate imply higher information?
# Not always.
# Information depends on:
# variability
# stimulus dependence
# not just spike count.
