# %% [markdown]
# <div align="center">
#
# ### Lab 03 | Neural Coding: From Spikes to Information
#
# ---
#
# **Programming Environment:** Python
# **Libraries:** NumPy • Matplotlib
#
# </div>
#
# ---
#
# #### Learning Outcomes
#
# By completing this lab, you will be able to:
#
# ---
# ###
# 1.	Explain the difference between rate coding and temporal coding
# 2.  Simulate spike trains using probabilistic models
# 3.  Understand how refractory periods limit firing rates
# 4.  Analyze inter-spike intervals (ISI)
# 5.  Demonstrate how population size improves decoding accuracy
# 6.  Interpret how biological constraints shape neural information processing

# %% [markdown]
# ### Part A — Spike trains as a code (Poisson model)
# Goal: Show that spikes are discrete events and coding often happens in rate or timing.

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(42)

T = 2.0          # seconds
dt = 0.001       # 1 ms
t = np.arange(0, T, dt)

def poisson_spikes(rate_hz, t, dt):
    p = rate_hz * dt
    return (np.random.rand(len(t)) < p).astype(int)

rate = 20  # Hz
spikes = poisson_spikes(rate, t, dt)

plt.figure(figsize=(10,2))
plt.eventplot(t[spikes==1])
plt.title(f"Spike train (Poisson) rate={rate} Hz")
plt.xlabel("Time (s)")
plt.show()

print("Estimated rate (Hz):", spikes.sum()/T)
# Out:
# Estimated rate (Hz): 17.0

# %%
# TODO 1:
# Change rate = 5, 20, 50 and observe the raster + estimated rate.
#Add a rate estimator using a sliding window (students implement a simple moving average).

def sliding_rate(spikes, window_ms=100, dt=0.001):
    window_size = int(window_ms/1000 / dt)
    kernel = np.ones(window_size)
    rate_est = np.convolve(spikes, kernel, mode='same') / (window_size*dt)
    return rate_est

rate_est = sliding_rate(spikes, window_ms=100)
plt.figure()
plt.plot(t, rate_est)
plt.title("Sliding Window Rate Estimate (100 ms)")
plt.xlabel("Time (s)")
plt.ylabel("Estimated Rate (Hz)")
plt.show()

# %% [markdown]
# ### Part B — Refractory period (biophysical constraint)
# Goal : Show that biology imposes limits on maximum firing rate.

# %%
def poisson_spikes_with_refractory(rate_hz, t, dt, refrac_s=0.01):
    p = rate_hz * dt
    spikes = np.zeros(len(t), dtype=int)
    last_spike_t = -np.inf
    for i, ti in enumerate(t):
        if (ti - last_spike_t) >= refrac_s:
            if np.random.rand() < p:
                spikes[i] = 1
                last_spike_t = ti
    return spikes

rate = 80
sp_no_ref = poisson_spikes(rate, t, dt)
sp_ref = poisson_spikes_with_refractory(rate, t, dt, refrac_s=0.01)

print("No ref rate:", sp_no_ref.sum()/T)
print("With ref rate:", sp_ref.sum()/T)
# Out:
# No ref rate: 91.5
# With ref rate: 45.5

# %%
# TODO 2:
# Vary refrac_s (2ms, 5ms, 10ms) and plot achieved firing rate vs refractory.
#Compute ISI (inter-spike interval) distribution and show the “gap” caused by refractory.
#(You must write the ISI code.)
#What happen when refactor increase?
# Larger refractory → lower achievable firing rate
# Minimum ISI increases
# Firing becomes more regular
# Maximum firing rate decreases
# Spike variability reduces
refracs = [0.002, 0.005, 0.01]  # 2ms, 5ms, 10ms
achieved_rates = []

for rfr in refracs:
    sp = poisson_spikes_with_refractory(rate, t, dt, refrac_s=rfr)
    achieved_rates.append(sp.sum()/T)

plt.figure()
plt.plot([r*1000 for r in refracs], achieved_rates, marker='o')
plt.xlabel("Refractory (ms)")
plt.ylabel("Achieved firing rate (Hz)")
plt.title("Firing rate vs Refractory period")
plt.show()

def compute_isi(spikes, t):
    spike_times = t[spikes == 1]
    return np.diff(spike_times)

isi_no_ref = compute_isi(sp_no_ref, t)
isi_ref = compute_isi(sp_ref, t)

plt.figure()
plt.hist(isi_no_ref, bins=50, alpha=0.5, label="No refractory")
plt.hist(isi_ref, bins=50, alpha=0.5, label="With refractory")
plt.xlabel("Inter-spike interval (s)")
plt.ylabel("Count")
plt.legend()
plt.show()

# %% [markdown]
# ### Part C — Rate coding experiment (stimulus intensity → firing rate)
#
# Goal: Show “intensity” is encoded by spike rate, not spike amplitude.

# %%
stim_levels = np.array([0.1, 0.2, 0.4, 0.8, 1.2])  # arbitrary stimulus
base = 5
gain = 30

rates = base + gain / (1 + np.exp(-5*(stim_levels-0.5)))  # simple encoding model

estimated = []
for r in rates:
    sp = poisson_spikes(r, t, dt)
    estimated.append(sp.sum()/T)

plt.figure()
plt.plot(stim_levels, rates, marker='o', label="True rate model")
plt.plot(stim_levels, estimated, marker='o', label="Estimated from spikes")
plt.xlabel("Stimulus level (a.u.)")
plt.ylabel("Firing rate (Hz)")
plt.title("Rate coding: stimulus → firing rate")
plt.legend()
plt.show()

# %%
# TODO 3: 
#Modify the encoding model: make it nonlinear (e.g., sigmoid or saturation).
#Add noise to stimulus and check stability of rate estimation.
#Explain what happen to the Raster plot and rate estimation. (1-2 sentenses)


noise_std = 0.1
estimated_noisy = []

for s in stim_levels:
    noisy_s = s + np.random.normal(0, noise_std)
    r = base + gain*noisy_s
    sp = poisson_spikes(r, t, dt)
    estimated_noisy.append(sp.sum()/T)

plt.figure()
plt.plot(stim_levels, rates, marker='o', label="True rate model")
plt.plot(stim_levels, estimated_noisy, marker='o', label="Estimated from spikes")
plt.xlabel("Stimulus level (a.u.)")
plt.ylabel("Firing rate (Hz)")
plt.title("Rate coding: stimulus → firing rate")
plt.legend()
plt.show()

# %% [markdown]
# As encoding becomes nonlinear (sigmoid), firing rate saturates at high stimulus values. Adding stimulus noise increases variability in rate estimation, especially at low spike counts.
# Raster:
# Higher stimulus → denser spikes
# Noise → more trial variability

# %% [markdown]
# ### Part D — Timing code (precision/jitter matters)
# Goal: Show that information can be carried by precise spike timing, not just counts.

# %%
def jitter_spike_times(spike_times, jitter_std, rng=np.random):
    return spike_times + rng.normal(0, jitter_std, size=len(spike_times))

true_times = np.array([0.5, 1.0, 1.5])  # “coded” event times
jitters = [0.0, 0.002, 0.005, 0.01]      # 0–10 ms jitter

plt.figure(figsize=(10,3))
for j in jitters:
    obs = jitter_spike_times(true_times, j)
    plt.plot(obs, np.ones_like(obs)*j, 'o')
plt.yticks(jitters, [f"{int(j*1000)} ms" for j in jitters])
plt.xlabel("Spike time (s)")
plt.title("Spike timing jitter")
plt.show()

# %%
# TODO 4:
#Implement a coincidence detector: count how often spikes fall within a window of a target time.
#Plot detection rate vs jitter.

def coincidence_detection(observed, target_times, window=0.005):
    count = 0
    for tt in target_times:
        if np.any(np.abs(observed - tt) <= window):
            count += 1
    return count / len(target_times)

detections = []

for j in jitters:
    rates = []
    for _ in range(100):
        obs = jitter_spike_times(true_times, j)
        rates.append(coincidence_detection(obs, true_times))
    detections.append(np.mean(rates))

plt.figure()
plt.plot([j*1000 for j in jitters], detections, marker='o')
plt.xlabel("Jitter (ms)")
plt.ylabel("Detection rate")
plt.title("Timing detection vs jitter")
plt.show()

# %% [markdown]
# ### Part E — Population coding + simple decoding
# Goal: Show that populations reduce noise and enable decoding.
#
# #### Baseline (run): We simulate two stimuli A and B that produce different population rates.

# %%
def simulate_population(stim, N=30, T=1.0, dt=0.001):
    t = np.arange(0, T, dt)
    # different rate patterns across neurons
    if stim == "A":
        rates = np.linspace(5, 25, N)
    else:
        rates = np.linspace(25, 5, N)
    spikes = np.array([poisson_spikes(r, t, dt) for r in rates])
    features = spikes.sum(axis=1) / T  # firing rate per neuron (Hz)
    return features

# dataset
X = []
y = []
for _ in range(200):
    X.append(simulate_population("A"))
    y.append(0)
    X.append(simulate_population("B"))
    y.append(1)

X = np.array(X)
y = np.array(y)

# simple linear decoder (no sklearn)
w = X[y==1].mean(axis=0) - X[y==0].mean(axis=0)
b = -0.5 * (X[y==1].mean(axis=0) + X[y==0].mean(axis=0)) @ w

pred = ((X @ w + b) > 0).astype(int)
acc = (pred == y).mean()
print("Decoding accuracy:", acc)
# Out:
# Decoding accuracy: 1.0

# %%
# TODO 5:

# Vary population size N: test N = 5, 10, 20, 50 and plot accuracy vs N.

# Add shared noise (correlation) and observe decoding accuracy drop.
Ns = [5, 10, 20, 50]
accuracies = []

for N in Ns:
    X = []
    y = []
    for _ in range(200):
        X.append(simulate_population("A", N=N))
        y.append(0)
        X.append(simulate_population("B", N=N))
        y.append(1)

    X = np.array(X)
    y = np.array(y)

    w = X[y==1].mean(axis=0) - X[y==0].mean(axis=0)
    b = -0.5 * (X[y==1].mean(axis=0) + X[y==0].mean(axis=0)) @ w

    pred = ((X @ w + b) > 0).astype(int)
    acc = (pred == y).mean()
    accuracies.append(acc)

plt.figure()
plt.plot(Ns, accuracies, marker='o')
plt.xlabel("Population size (N)")
plt.ylabel("Decoding accuracy")
plt.title("Accuracy vs Population Size")
plt.show()

# %%
def simulate_population(stim, N=30, T=1.0, dt=0.001, shared_noise=0):
    t = np.arange(0, T, dt)
    if stim == "A":
        rates = np.linspace(5, 25, N)
    else:
        rates = np.linspace(25, 5, N)

    common = np.random.normal(0, shared_noise)
    spikes = np.array([poisson_spikes(r+common, t, dt) for r in rates])
    features = spikes.sum(axis=1) / T
    return features

# %% [markdown]
# #### Writing questions.
#
# 1. Rate coding vs timing coding (2–3 sentences)
#    Rate coding represents information in the average firing rate over time, while timing coding represents information through precise spike timing. Rate coding is robust but slower, whereas timing coding allows rapid and precise information transmission.
#
# 2. What refractory changes
#    Increasing refractory period limits maximum firing rate, increases minimum inter-spike interval, and makes spike trains more regular. It imposes a biological constraint on information transmission
#
# 3. How population size affects decoding
#     Larger populations improve decoding accuracy because noise averages out across neurons. However, correlated noise reduces this advantage.
